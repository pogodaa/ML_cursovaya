# %% [markdown]
# Привет, ситуация следующая. Я писал куросовую по ML, по временным рядам и из за отсутсвия знаний обучил 3 модели (RandomForest, XGBoost, Lightgbm), но они никак не подходят для временных рядов. Анализ EDA я сделал. У меня так же есть пример курсовой которая уже защитилась и она тоже по временным рядам. Мой тема курсовой «Прогнозирование суточной нагрузки в электросети на основе анализа временных рядов и сезонных факторов». Мне нужно чтобы ты запомнил мой eda анализ, переобучил на моделях которые нашёл. ТАк давай начнём, скажи что тебе нужно?

# %% [markdown]
# так смотри main.ipynb это EDA анализ.
#
# Далее model_not_valid это обучение моделей RandomForest, LightGBM, XGBoost.
#
# Далее model.ipynb это обучение моделей которые работают с временными рядами
