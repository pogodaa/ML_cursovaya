# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Агрегация данных по часам (для ARIMA лучше меньше точек)
hourly_data = df['Global_active_power'].resample('H').mean()
daily_data = df['Global_active_power'].resample('D').mean()

print(f"Часовые данные: {len(hourly_data)} точек")
print(f"Суточные данные: {len(daily_data)} точек")
